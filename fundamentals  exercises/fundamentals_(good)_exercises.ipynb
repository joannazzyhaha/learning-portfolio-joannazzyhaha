# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good) Exercises</span></div>

# %%
user_input = input('Give me a number?')
print('You entered', user_input)
# Out:
# Give me a number? 2
# You entered 2

# %%
grades = {
    'grade_A' : 'A', 
    'grade_B' : 'B',
    'grade_C' : 'C'
}
score = float(input('score'))

if 70 <= score <= 100:
    print(grades['grade_A'])
elif 50 <= score <= 69:
    print(grades['grade_B'])
elif 35 <= score <= 49:
    print(grades['grade_C'])
else:
    print('Fail')

user_input = input('score')

print('your grade', grades)

#WHY DOES IT ONLY WORK ONE TIME???
# Out:
# score 0
# Fail
# score 0
# your grade {'grade_A': 'A', 'grade_B': 'B', 'grade_C': 'C'}
